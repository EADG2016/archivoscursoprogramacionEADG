# %% [markdown]
# Diseña un programa en PYTHON para cada uno de los problemas
# que se te plantean.
#
# 1. Crear un bucle que cuente todos los números pares hasta
# el 100 ciclo for

# %%
acu = 0

for i in range(0,101,2):
  # print(i)
  acu = acu + i
print(f"El total de la suma de los número pares del 0-100= {acu}")
# Out:
# El total de la suma de los número pares del 0-100= 2550

# %% [markdown]
# 2. Haz una tabla de multiplicar utilizando el ciclo for
# ciclo for

# %%
num = int(input("Digite el número de la tabla de multiplicar: "))

for i in range(11):
  print(i, " x ", num, " = ",  i * num)
# Out:
# Digite el número de la tabla de multiplicar: 5
# 0  x  5  =  0
# 1  x  5  =  5
# 2  x  5  =  10
# 3  x  5  =  15
# 4  x  5  =  20
# 5  x  5  =  25
# 6  x  5  =  30
# 7  x  5  =  35
# 8  x  5  =  40
# 9  x  5  =  45
# 10  x  5  =  50

# %% [markdown]
# 3. Escribir un programa que pregunte al usuario su edad y
# muestre por pantalla todos los años que ha cumplido
# (desde 1 hasta su edad). ciclo for

# %%
Edad = int(input("Digite su edad: "))

for i in range(Edad):
    print("Has cumplido " + str(i+1) + " años")
# Out:
# Digite su edad: 42
# Has cumplido 1 años
# Has cumplido 2 años
# Has cumplido 3 años
# Has cumplido 4 años
# Has cumplido 5 años
# Has cumplido 6 años
# Has cumplido 7 años
# Has cumplido 8 años
# Has cumplido 9 años
# Has cumplido 10 años
# Has cumplido 11 años
# Has cumplido 12 años
# Has cumplido 13 años
# Has cumplido 14 años
# Has cumplido 15 años
# Has cumplido 16 años
# Has cumplido 17 años
# Has cumplido 18 años
# Has cumplido 19 años
# Has cumplido 20 años
# Has cumplido 21 años
# Has cumplido 22 años
# Has cumplido 23 años
# Has cumplido 24 años
# Has cumplido 25 años
# Has cumplido 26 años
# Has cumplido 27 años
# Has cumplido 28 años
# Has cumplido 29 años
# Has cumplido 30 años
# Has cumplido 31 años
# Has cumplido 32 años
# Has cumplido 33 años
# Has cumplido 34 años
# Has cumplido 35 años
# Has cumplido 36 años
# Has cumplido 37 años
# Has cumplido 38 años
# Has cumplido 39 años
# Has cumplido 40 años
# Has cumplido 41 años
# Has cumplido 42 años

# %% [markdown]
# 4. Escribir un programa que pida al usuario un número entero
# positivo y muestre por pantalla todos los números
# impares desde 1 hasta ese número separados por comas.

# %%
n = int(input("Introduce un número entero positivo: "))
for i in range(n, -1, -1):
    print(i, end=", ")
# Out:
# Introduce un número entero positivo: 7
# 7, 6, 5, 4, 3, 2, 1, 0,

# %% [markdown]
# 5. Encuentra la suma de todos los números pares del 1 al
# 100 ciclo for

# %%
acu = 0

for i in range(0,101,2):
  # print(i)
  acu = acu + i
  print("la suma de todos los numeros pares de 1 al", i, "es de", acu)
# Out:
# la suma de todos los numeros pares de 1 al 0 es de 0
# la suma de todos los numeros pares de 1 al 2 es de 2
# la suma de todos los numeros pares de 1 al 4 es de 6
# la suma de todos los numeros pares de 1 al 6 es de 12
# la suma de todos los numeros pares de 1 al 8 es de 20
# la suma de todos los numeros pares de 1 al 10 es de 30
# la suma de todos los numeros pares de 1 al 12 es de 42
# la suma de todos los numeros pares de 1 al 14 es de 56
# la suma de todos los numeros pares de 1 al 16 es de 72
# la suma de todos los numeros pares de 1 al 18 es de 90
# la suma de todos los numeros pares de 1 al 20 es de 110
# la suma de todos los numeros pares de 1 al 22 es de 132
# la suma de todos los numeros pares de 1 al 24 es de 156
# la suma de todos los numeros pares de 1 al 26 es de 182
# la suma de todos los numeros pares de 1 al 28 es de 210
# la suma de todos los numeros pares de 1 al 30 es de 240
# la suma de todos los numeros pares de 1 al 32 es de 272
# la suma de todos los numeros pares de 1 al 34 es de 306
# la suma de todos los numeros pares de 1 al 36 es de 342
# la suma de todos los numeros pares de 1 al 38 es de 380
# la suma de todos los numeros pares de 1 al 40 es de 420
# la suma de todos los numeros pares de 1 al 42 es de 462
# la suma de todos los numeros pares de 1 al 44 es de 506
# la suma de todos los numeros pares de 1 al 46 es de 552
# la suma de todos los numeros pares de 1 al 48 es de 600
# la suma de todos los numeros pares de 1 al 50 es de 650
# la suma de todos los numeros pares de 1 al 52 es de 702
# la suma de todos los numeros pares de 1 al 54 es de 756
# la suma de todos los numeros pares de 1 al 56 es de 812
# la suma de todos los numeros pares de 1 al 58 es de 870
# la suma de todos los numeros pares de 1 al 60 es de 930
# la suma de todos los numeros pares de 1 al 62 es de 992
# la suma de todos los numeros pares de 1 al 64 es de 1056
# la suma de todos los numeros pares de 1 al 66 es de 1122
# la suma de todos los numeros pares de 1 al 68 es de 1190
# la suma de todos los numeros pares de 1 al 70 es de 1260
# la suma de todos los numeros pares de 1 al 72 es de 1332
# la suma de todos los numeros pares de 1 al 74 es de 1406
# la suma de todos los numeros pares de 1 al 76 es de 1482
# la suma de todos los numeros pares de 1 al 78 es de 1560
# la suma de todos los numeros pares de 1 al 80 es de 1640
# la suma de todos los numeros pares de 1 al 82 es de 1722
# la suma de todos los numeros pares de 1 al 84 es de 1806
# la suma de todos los numeros pares de 1 al 86 es de 1892
# la suma de todos los numeros pares de 1 al 88 es de 1980
# la suma de todos los numeros pares de 1 al 90 es de 2070
# la suma de todos los numeros pares de 1 al 92 es de 2162
# la suma de todos los numeros pares de 1 al 94 es de 2256
# la suma de todos los numeros pares de 1 al 96 es de 2352
# la suma de todos los numeros pares de 1 al 98 es de 2450
# la suma de todos los numeros pares de 1 al 100 es de 2550
