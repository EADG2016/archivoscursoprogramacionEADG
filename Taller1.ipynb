# %%
N_de_Identificación = (80150459)
print(N_de_Identificación)
Nombres = "Elías Alberto"
print(Nombres)
Apellidos = "Durán González"
print(Apellidos)
Dirección = "Cra 71f N° 5a - 54"
print(Dirección)
telefono = (3138131138)
print(telefono)
Edad = "42 años"
print(Edad)
nombre_per = input("estado civil: ")
print(nombre_per)
Numero_de_hijos = (1)
print(Numero_de_hijos)
Estatura_en_centímetros = "175 cm"
print(Estatura_en_centímetros)
fecha_de_contratación_Día = "01"
fecha_de_contratación_Mes = "01"
fecha_de_contratación_año = "1998"
print(fecha_de_contratación_Día + "/" + fecha_de_contratación_Mes + "/" + fecha_de_contratación_año)
Sueldo_basico = "$5.000.000"
print(Sueldo_basico)
Días_laborados = (4561)
print(Días_laborados)
# Out:
# 80150459
# Elías Alberto
# Durán González
# Cra 71f N° 5a - 54
# 3138131138
# 42 años
# estado civil: Casado
# Casado
# 1
# 175 cm
# 01/01/1998
# $5.000.000
# 4561
